# %% [markdown]
# 1. ##### [Top 5 Error Rate](https://machinelearning.wtf/terms/top-5-error-rate/)
# The model is considered to have classified a given image correctly if the target label is one of the model’s top 5 predictions.
